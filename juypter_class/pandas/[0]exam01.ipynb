# %%
import pandas as  pd

# %%
#1 employee.csv를 읽어오자
df = pd.read_csv('data/employee.csv')
df
# Out:
#   ename deptname addr          phone
# 0   kim      관리직  서울시  010-1111-1111
# 1  park      관리직  부산시  010-2222-2222
# 2   lee      영업직  광주시  010-3333-3333
# 3   min      영업직  광주시  010-4444-4444
# 4  song      개발직  광주시  010-5555-5555

# %%
#2 칼럼 추출
df.columns
# Out:
# Index(['ename', 'deptname', 'addr', 'phone'], dtype='object')

# %%
#3 행 추출
df.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 #3 행 추출
#       2 #df.index
# ----> 3 df.itemrows
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'itemrows'

# %%
#4 df값만 추출해보자
df.values
# Out:
# array([['kim', '관리직', '서울시', '010-1111-1111'],
#        ['park', '관리직', '부산시', '010-2222-2222'],
#        ['lee', '영업직', '광주시', '010-3333-3333'],
#        ['min', '영업직', '광주시', '010-4444-4444'],
#        ['song', '개발직', '광주시', '010-5555-5555']], dtype=object)

# %%
#5 df의 컬럼명을 리턴받아 확인 후 한글로 컬럼명을 변경해서 df.values로 my_emp.csv로 저장해보자
df.rename(columns={'ename':'이름','deptname':'부서','addr':'주소','phone':'전화번호'})
df.to_csv('data/my_emp.csv',index =False , encoding='utf-8')

# %%
#6 my_emp.csv로드해서 출력 해보자
res = pd.read_csv('data/my_emp.csv')
res
# Out:
#   ename deptname addr          phone
# 0   kim      관리직  서울시  010-1111-1111
# 1  park      관리직  부산시  010-2222-2222
# 2   lee      영업직  광주시  010-3333-3333
# 3   min      영업직  광주시  010-4444-4444
# 4  song      개발직  광주시  010-5555-5555

# %%
#7 res객체에 인덱스를 추가해서 사용해보자
index_m = ['사원1','사원2','사원3','사원4','사원5']
df = pd.DataFrame(res.values,index=index_m ,columns =['이름','부서','주소','전화번호'])
df
# Out:
#        이름   부서   주소           전화번호
# 사원1   kim  관리직  서울시  010-1111-1111
# 사원2  park  관리직  부산시  010-2222-2222
# 사원3   lee  영업직  광주시  010-3333-3333
# 사원4   min  영업직  광주시  010-4444-4444
# 사원5  song  개발직  광주시  010-5555-5555

# %%
#8 df를 엑셀로 저장해보자
df.to_excel("data/my_emp.xlsx",index=False )

# %%
csv =pd.read_excel('data/my_emp.xlsx')
csv
# Out:
#      이름   부서   주소           전화번호
# 0   kim  관리직  서울시  010-1111-1111
# 1  park  관리직  부산시  010-2222-2222
# 2   lee  영업직  광주시  010-3333-3333
# 3   min  영업직  광주시  010-4444-4444
# 4  song  개발직  광주시  010-5555-5555

# %%
#9 이름과 주소만 추출해서 출력하자
res_df = csv[["이름","주소"]]
res_df
# Out:
#      이름   주소
# 0   kim  서울시
# 1  park  부산시
# 2   lee  광주시
# 3   min  광주시
# 4  song  광주시

# %%
#10 df테이블의 주소가 서울시인 레코드만 출력 해보자
r1 = df[df["주소"] =='서울시']
r1
# Out:
#       이름   부서   주소           전화번호
# 사원1  kim  관리직  서울시  010-1111-1111

# %%
#11 df 테이블으 영업직 레코드 추출
r2 = df[df["부서"] =='영업직']
r2
# Out:
#       이름   부서   주소           전화번호
# 사원3  lee  영업직  광주시  010-3333-3333
# 사원4  min  영업직  광주시  010-4444-4444

# %%
#12 df 테이블의 lee 이면서 영엽직 추출
r3 = df.loc[(df['이름']=='lee') & (df['부서']=='영업직')]
r3
# Out:
#       이름   부서   주소           전화번호
# 사원3  lee  영업직  광주시  010-3333-3333

# %%
#13 df 테이블의 kim 이면서 서울시 추출
#r4 = df.loc[(df['이름']=='kim') & (df['주소']=='서울시')]
r4 = df[(df['이름']=='kim') & (df['주소']=='서울시')]
r4
# Out:
#       이름   부서   주소           전화번호
# 사원1  kim  관리직  서울시  010-1111-1111

# %%
#14 df 테이블의 관리직 추출
r5 = df[df["부서"] =='관리직']
r5
# Out:
#        이름   부서   주소           전화번호
# 사원1   kim  관리직  서울시  010-1111-1111
# 사원2  park  관리직  부산시  010-2222-2222

# %%
#15 df 테이블의 이름,주소,전화번호만 추출 my_profile.csv 로 저장
r6 = df[['이름','주소','전화번호']]
r6.to_csv("data/my_profile.csv",index=False )
r6
# Out:
#        이름   주소           전화번호
# 사원1   kim  서울시  010-1111-1111
# 사원2  park  부산시  010-2222-2222
# 사원3   lee  광주시  010-3333-3333
# 사원4   min  광주시  010-4444-4444
# 사원5  song  광주시  010-5555-5555

# %%
#16 df 테이블의 이름,부서만 추출 my_dept.csv 로 저장
r7 = df[['이름','부서']]
r7.to_csv("data/my_dept.csv",index=False )
r7
# Out:
#        이름   부서
# 사원1   kim  관리직
# 사원2  park  관리직
# 사원3   lee  영업직
# 사원4   min  영업직
# 사원5  song  개발직

# %%
#17 .inner join = 여러개의 테이블을 병합할 때 같은 데이터만 추려서 병합한다
hap_df = pd.merge(res_df,r7,how='inner',on='이름')
hap_df
# select *
# from res_df join r7  using ("이름")
# Out:
#      이름   주소   부서
# 0   kim  서울시  관리직
# 1  park  부산시  관리직
# 2   lee  광주시  영업직
# 3   min  광주시  영업직
# 4  song  광주시  개발직

# %%
#18 iloc[0:3,[0,2]] , loc[df['이름']] 
df.loc[(df['이름']=='kim') & (df['주소']=='서울시')]
# Out:
#       이름   부서   주소           전화번호
# 사원1  kim  관리직  서울시  010-1111-1111

# %%
df.iloc[0:2,[0,2]]
# Out:
#        이름   주소
# 사원1   kim  서울시
# 사원2  park  부산시

# %%
df.iloc[0:2,::-2]
# Out:
#               전화번호   부서
# 사원1  010-1111-1111  관리직
# 사원2  010-2222-2222  관리직

# %%
help(df.loc)
# Out:
# Help on _LocIndexer in module pandas.core.indexing object:
#
# class _LocIndexer(_LocationIndexer)
#  |  Access a group of rows and columns by label(s) or a boolean array.
#  |
#  |  ``.loc[]`` is primarily label based, but may also be used with a
#  |  boolean array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#  |    interpreted as a *label* of the index, and **never** as an
#  |    integer position along the index).
#  |  - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#  |  - A slice object with labels, e.g. ``'a':'f'``.
#  |
#  |    .. warning:: Note that contrary to usual python slices, **both** the
#  |        start and the stop are included
#  |
#  |  - A boolean array of the same length as the axis being sliced,
#  |    e.g. ``[True, False, True]``.
#  |  - An alignable boolean Series. The index of the key will be aligned before
#  |    masking.
# ...
