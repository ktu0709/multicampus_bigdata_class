# %%
# matplotlib에서 한글 폰트를 설정하는 방법
import matplotlib.pyplot as plt
plt.rc("font", family="malgun gothic")

# 음수 기호 출력 방법
import matplotlib
matplotlib.rcParams["axes.unicode_minus"]=False

# 그래프를 선명하게 출력하는 방법
# %config InlineBackend.figure_format = "retina"

import numpy as np

# %%
from sklearn.datasets import make_circles

x, y = make_circles(n_samples=1000, noise=0.05, factor=0.5)

print(x.shape)
x1 = x[:,0]
x2 = x[:,1]

plt.scatter(x1,x2,edgecolor="black")
plt.axis("square")
plt.show()
# Out:
# (1000, 2)

# %%
# DBSCAN: 밀도 기반 클러스터링
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.2, # 반경
                min_samples=10) # 군집화를 위한 최소 샘플 갯수
dbscan.fit(x)
# Out:
# DBSCAN(eps=0.2, min_samples=10)

# %%
labels = dbscan.labels_
# print(labels) # 각 데이터별 군집화된 번호

plt.scatter(x[labels == 0, 0], x[labels == 0, 1],
            color="lightblue", edgecolor="black")

plt.scatter(x[labels == 1, 0], x[labels == 1, 1],
            color="orange", edgecolor="black")

plt.axis("square")
plt.show()
