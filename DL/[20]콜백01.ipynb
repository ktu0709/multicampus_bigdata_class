# %% [markdown]
# 콜백함수란? 어떤 함수를 수행 시 그 함수에서 사용자가 지정한 함수를 호출하는 것.

# %%
#Q1. 데이터를 생성하여 훈련 데이터와 테스트 데이터로 나누어 훈련 데이터를 시각화 해보자.

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dense
#from keras.layers.core import Dense



data, target = make_circles(n_samples=2000, noise=0.2, factor=0.3)
X_train, X_test, y_train, y_test = train_test_split(
                                            data,
                                            target,
                                            test_size=0.2,
                                            stratify=target)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1, aspect='equal', xlim=(-2, 2), ylim=(-2, 2))
ax.scatter(X_train[y_train == 0, 0], X_train[y_train == 0, 1], marker="o")
ax.scatter(X_train[y_train == 1, 0], X_train[y_train == 1, 1], marker="x")
plt.show()

# %%
#Q2) 간단한 신경망을 만들어 확인 

model = Sequential()
model.add(Dense(16, activation='tanh', input_shape=(2,)))
model.add(Dense(1, activation='sigmoid'))
model.summary()
model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=['acc']
)
# Out:
# WARNING:tensorflow:From C:\Users\taeeon.kim\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                48
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 65 (260.00 Byte)
# Trainable params: 65 (260.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\taeeon.kim\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#Q3) 학습 
history = model.fit(
                    X_train,
                    y_train,
                    epochs=100,
                    batch_size=32,
                    validation_data=[X_test, y_test]
            )
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\taeeon.kim\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\taeeon.kim\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 50/50 [==============================] - 1s 6ms/step - loss: 0.6975 - acc: 0.5362 - val_loss: 0.6899 - val_acc: 0.6275
# Epoch 2/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6928 - acc: 0.6369 - val_loss: 0.6907 - val_acc: 0.6400
# Epoch 3/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6911 - acc: 0.5263 - val_loss: 0.6912 - val_acc: 0.5175
# Epoch 4/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6901 - acc: 0.5444 - val_loss: 0.6909 - val_acc: 0.5150
# Epoch 5/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6896 - acc: 0.5344 - val_loss: 0.6902 - val_acc: 0.5050
# Epoch 6/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6888 - acc: 0.5512 - val_loss: 0.6900 - val_acc: 0.5250
# Epoch 7/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6878 - acc: 0.5894 - val_loss: 0.6891 - val_acc: 0.5625
# Epoch 8/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6872 - acc: 0.5225 - val_loss: 0.6879 - val_acc: 0.5325
# Epoch 9/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6856 - acc: 0.5350 - val_loss: 0.6868 - val_acc: 0.5375
# Epoch 10/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6845 - acc: 0.5537 - val_loss: 0.6858 - val_acc: 0.5500
# Epoch 11/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6833 - acc: 0.5881 - val_loss: 0.6844 - val_acc: 0.5600
# Epoch 12/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6817 - acc: 0.5781 - val_loss: 0.6830 - val_acc: 0.5700
# Epoch 13/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6799 - acc: 0.5794 - val_loss: 0.6808 - val_acc: 0.5600
# Epoch 14/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6779 - acc: 0.5631 - val_loss: 0.6780 - val_acc: 0.5350
# Epoch 15/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6757 - acc: 0.5631 - val_loss: 0.6763 - val_acc: 0.5975
# Epoch 16/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.
ras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto')
#
#     값의 변화가 정지했을 때에 훈련을 종료하는 목적을 가진 메소드
#
#
# - monitor : 모니터링 할 값.
# - min_delta : 모니터링 할 값에 대해 개선으로 결정되는 최소 변화 값. 즉, min_delta보다 절대치의 변화가 작으면 개선되어 있지 않다고 판단
# - patience : 여기에 지정된 에포크 수 동안 (감시하는 값에) 개선이 없으면 훈련이 중지
# - verbose : 중복 모드.
# - mode : {auto, min, max} 중 하나가 선택.
#   - min : 모니터링 할 값의 감소가 중지되면 훈련이 종료
#   - max : 모니터링 할 값의 증가가 중지되면 훈련이 종료.
#   - auto:  자동으로 모니터링되는 값

# %% [raw]
# tf.keras.callbacks.EarlyStopping(
#     monitor='val_loss', #모니터링 지표값
#     min_delta=0, #최소 변화량
#     patience=0, #지정된 에폭 수 동안 모니터링 지표의 개선이 없을 때 학습을 중지 ex) 10주면 10에폭동안 개선이 없으면 중지
#     verbose=0,
#     mode='auto',
#     baseline=None, #지정된 수치값보다 개선되지 않으면 학습을 종료
#     restore_best_weights=False, #마지막 학습된 가중치가 유지
#     start_from_epoch=0
# )

# %%
from keras.callbacks import EarlyStopping


early_stopping =  EarlyStopping(
                            monitor='val_loss',
                            min_delta=0.0,
                            patience=2,verbose=1,restore_best_weights=True
)

history = model.fit(
                    X_train,
                    y_train,
                    epochs=100,
                    batch_size=16,
                    validation_data=[X_test, y_test],
                    callbacks=[early_stopping] 
            )# monitor에 설정된 값이 patience 값의 횟수를 계속해서 min_delta 이상 개선되지 않으면 학습이 중지
              # monitor에는 'val_loss' 외에 'val_acc'등도 설정할 수 있다.
# Out:
# Epoch 1/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1257 - acc: 0.9506 - val_loss: 0.1226 - val_acc: 0.9575
# Epoch 2/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1256 - acc: 0.9500 - val_loss: 0.1231 - val_acc: 0.9550
# Epoch 3/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1251 - acc: 0.9513 - val_loss: 0.1221 - val_acc: 0.9575
# Epoch 4/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1248 - acc: 0.9500 - val_loss: 0.1221 - val_acc: 0.9575
# Epoch 5/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1248 - acc: 0.9500 - val_loss: 0.1222 - val_acc: 0.9550
# Epoch 6/100
#  74/100 [=====================>........] - ETA: 0s - loss: 0.1256 - acc: 0.9493Restoring model weights from the end of the best epoch: 4.
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1245 - acc: 0.9506 - val_loss: 0.1224 - val_acc: 0.9550
# Epoch 6: early stopping

# %%
from keras.callbacks import EarlyStopping


early_stopping =  EarlyStopping(
                            monitor='val_loss',
                            min_delta=0.001,
                            patience=5,verbose=1,restore_best_weights=True)

history = model.fit(
                    X_train,
                    y_train,
                    epochs=100,
                    batch_size=16,
                    validation_data=[X_test, y_test],
                    callbacks=[early_stopping] 
            )# monitor에 설정된 값이 patience 값의 횟수를 계속해서 min_delta 이상 개선되지 않으면 학습이 중지
              # monitor에는 'val_loss' 외에 'val_acc'등도 설정할 수 있다.
# Out:
# Epoch 1/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1246 - acc: 0.9506 - val_loss: 0.1214 - val_acc: 0.9575
# Epoch 2/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1245 - acc: 0.9513 - val_loss: 0.1212 - val_acc: 0.9550
# Epoch 3/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1243 - acc: 0.9506 - val_loss: 0.1220 - val_acc: 0.9575
# Epoch 4/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1240 - acc: 0.9506 - val_loss: 0.1221 - val_acc: 0.9575
# Epoch 5/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1239 - acc: 0.9513 - val_loss: 0.1216 - val_acc: 0.9550
# Epoch 6/100
#  68/100 [===================>..........] - ETA: 0s - loss: 0.1278 - acc: 0.9485Restoring model weights from the end of the best epoch: 1.
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1241 - acc: 0.9494 - val_loss: 0.1214 - val_acc: 0.9575
# Epoch 6: early stopping

# %% [raw]
# early_stopping =  EarlyStopping(
#                             monitor='val_loss',
#                             min_delta=0.001,
#                             patience=5,)  최소손실보다 0.001 감소하지 않고 5 에폭동안 계속 증가하거나 개선되지 않으면 중단해라

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(2, 1, 1, title="loss")
ax.plot(history.epoch, history.history["loss"], label="train_loss")
ax.plot(history.epoch, history.history["val_loss"], linestyle="-.", label="val_loss")
ax.legend()

ax = fig.add_subplot(2, 1, 2, title="acc")
ax.plot(history.epoch, history.history["acc"], label="train_acc")
ax.plot(history.epoch, history.history["val_acc"], linestyle="-.", label="val_acc")
ax.legend()
plt.show()

# %%
from keras.callbacks import EarlyStopping


early_stopping =  EarlyStopping(
                            monitor='val_acc',
                            min_delta=0.001,
                            patience=10,
                            mode = 'max',
                            verbose=1,restore_best_weights=True)

history = model.fit(
                    X_train,
                    y_train,
                    epochs=100,
                    batch_size=16,
                    validation_data=[X_test, y_test],
                    callbacks=[early_stopping] 
                    )
# Out:
# Epoch 1/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1244 - acc: 0.9513 - val_loss: 0.1214 - val_acc: 0.9575
# Epoch 2/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1244 - acc: 0.9500 - val_loss: 0.1219 - val_acc: 0.9575
# Epoch 3/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1240 - acc: 0.9494 - val_loss: 0.1211 - val_acc: 0.9550
# Epoch 4/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1244 - acc: 0.9500 - val_loss: 0.1215 - val_acc: 0.9575
# Epoch 5/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1239 - acc: 0.9506 - val_loss: 0.1212 - val_acc: 0.9575
# Epoch 6/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1236 - acc: 0.9500 - val_loss: 0.1211 - val_acc: 0.9550
# Epoch 7/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1235 - acc: 0.9494 - val_loss: 0.1211 - val_acc: 0.9550
# Epoch 8/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1234 - acc: 0.9500 - val_loss: 0.1207 - val_acc: 0.9550
# Epoch 9/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1233 - acc: 0.9500 - val_loss: 0.1208 - val_acc: 0.9550
# Epoch 10/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1234 - acc: 0.9500 - val_loss: 0.1204 - val_acc: 0.9550
# Epoch 11/100
#  70/100 [====================>.........] - ETA: 0s - loss: 0.1172 - acc: 0.9527Restoring model weights from the end of the best epoch: 1.
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1231 - acc: 0.9513 - val_loss: 0.1207 - val_acc: 0.9575
# Epoch 11: early stopping
